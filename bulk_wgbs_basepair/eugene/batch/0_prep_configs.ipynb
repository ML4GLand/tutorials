# %%
import os
import glob
import yaml
import numpy as np
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %% [markdown]
# # Prep dataset config

# %%
path_config = "/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset/HepG2_WGBS.yaml"
path_out = "/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset"
os.makedirs(path_out, exist_ok=True)

# %%
config = yaml.safe_load(open(path_config, 'r'))
config
# Out:
# {'name': 'HepG2_WGBS',
#  'threads': 4,
#  'random_state': 1234,
#  'seqdata': {'fasta': '/cellar/users/aklie/data/ref/genomes/hg38/hg38.fa',
#   'seq_var': 'seq',
#   'bws': ['/cellar/users/aklie/data/datasets/SeqDatasets/HepG2_WGBS/processed/HepG2_WGBS_CpG_methylation_coverage_rep1.bigWig',
#    '/cellar/users/aklie/data/datasets/SeqDatasets/HepG2_WGBS/processed/ENCFF782HWK_HepG2_WGBS_CpG_sites_coverage_rep1.bigWig'],
#   'bw_names': ['CpG_methylation_coverage_rep1', 'CpG_sites_coverage_rep1'],
#   'cov_var': 'cov',
#   'loci': '/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.5kb_windows.bed',
#   'batch_size': 10000,
#   'fixed_length': 5000,
#   'target_length': 5000,
#   'alphabet': 'DNA',
#   'upper_case': False,
#   'add_rev_comp': False,
#   'max_jitter': 0},
#  'splits': '/cellar/users/aklie/projects/ML4GLand/tutorials/data/splits/ENCODE_cross-val.json'}

# %%
windows_bed = glob.glob("/cellar/users/aklie/data/ref/genomes/hg38/windows/*.bed")
windows_bed
# Out:
# ['/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.100kb_windows.bed',
#  '/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.500bp_windows.bed',
#  '/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.500bp_windows.sample.bed',
#  '/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.1kb_windows.bed',
#  '/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.5kb_windows.bed',
#  '/cellar/users/aklie/data/ref/genomes/hg38/windows/hg38.10kb_windows.bed']

# %%
config_paths = []
for window_bed in windows_bed:
    if "sample" in window_bed:
        continue
    config['seqdata']['loci'] = window_bed
    window_size = window_bed.split("/")[-1].split("_windows.bed")[0].split(".")[-1]
    curr_out = os.path.join(path_out, window_size, "HepG2_WGBS.yaml")
    # update seqdata.fixed_length and seqdata.target_length
    if window_size.endswith("bp"):
        config['seqdata']['fixed_length'] = int(window_size[:-2])
        config['seqdata']['target_length'] = int(window_size[:-2])
    elif window_size.endswith("kb"):
        config['seqdata']['fixed_length'] = int(window_size[:-2]) * 1000
        config['seqdata']['target_length'] = int(window_size[:-2]) * 1000
    os.makedirs(os.path.dirname(curr_out), exist_ok=True)
    with open(curr_out, 'w') as f:
        yaml.dump(config, f)
    print(curr_out)
    config_paths.append(curr_out)
# Out:
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset/100kb/HepG2_WGBS.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset/500bp/HepG2_WGBS.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset/1kb/HepG2_WGBS.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset/5kb/HepG2_WGBS.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/prep_dataset/10kb/HepG2_WGBS.yaml

# %%
# Save config_paths to .txt file in path_out
with open(os.path.join(path_out, "config_paths.txt"), 'w') as f:
    f.write("\n".join(config_paths))

# %%
# Make a dataframe with paths of configs in first column and output directory in second column
df = pd.DataFrame()
df["config"] = config_paths
df["out_dir"] = [os.path.dirname(p) for p in config_paths]
df.to_csv("/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_wgbs_basepair/eugene/batch/metadata/prep_dataset.tsv", sep="\t", index=False, header=False)

# %% [markdown]
# # Bias fit configs

# %%
path_config = "/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/K562_ATAC-seq_bias.yaml"
path_out = "/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model"

# %%
config = yaml.safe_load(open(path_config, 'r'))
config
# Out:
# {'name': 'K562_ATAC-seq_bias_fold_0',
#  'threads': 4,
#  'random_state': 1234,
#  'seqdata': {'path': '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.5/K562_ATAC-seq.minimal.seqdata',
#   'seq_var': 'seq',
#   'cov_var': 'cov',
#   'fold': 'fold_0',
#   'seq_length': 2114,
#   'target_length': 1000,
#   'max_jitter': 0,
#   'max_counts': 101,
#   'min_counts': 0,
#   'outlier_threshold': 0.9999},
#  'model': {'n_filters': 128, 'n_layers': 4, 'n_outputs': 1, 'alpha': None},
#  'training': {'learning_rate': 0.001,
#   'batch_size': 64,
#   'max_epochs': 50,
#   'validation_iter': 1000,
#   'rc_augment': True},
#  'evaluation': {'batch_size': 256},
#  'attribution': {'batch_size': 128, 'subsample': 30000, 'n_shuffles': 20},
#  'modisco': {'n_seqlets': 50000,
#   'window': 500,
#   'motif_db': '/cellar/users/aklie/projects/ML4GLand/tutorials/data/motifs.meme.txt'}}

# %%
seqdatas = {}
for f in glob.glob(os.path.join(os.path.dirname(path_out), "prep_dataset", "*", "*.minimal.seqdata"), recursive=True):
    signal_beta = float(os.path.basename(os.path.dirname(f)))
    seqdatas[signal_beta] = f
seqdatas
# Out:
# {0.5: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.5/K562_ATAC-seq.minimal.seqdata',
#  0.8: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.8/K562_ATAC-seq.minimal.seqdata',
#  0.2: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.2/K562_ATAC-seq.minimal.seqdata',
#  0.6: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.6/K562_ATAC-seq.minimal.seqdata',
#  0.1: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.1/K562_ATAC-seq.minimal.seqdata',
#  0.3: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.3/K562_ATAC-seq.minimal.seqdata',
#  0.9: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.9/K562_ATAC-seq.minimal.seqdata',
#  0.4: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.4/K562_ATAC-seq.minimal.seqdata',
#  0.7: '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/prep_dataset/0.7/K562_ATAC-seq.minimal.seqdata'}

# %%
# Need to pull out Max Negative Counts: value from the following
reports = {}
for f in glob.glob(os.path.join(os.path.dirname(path_out), "prep_dataset", "*", "*.report.html"), recursive=True):
    signal_beta = float(os.path.basename(os.path.dirname(f)))
    with open(f, 'r') as f:
        content = f.read()
        max_neg_counts = float(content.split("Max Negative Counts: ")[1].split(",")[0])
        reports[signal_beta] = max_neg_counts
reports
# Out:
# {0.5: 103.0,
#  0.8: 165.0,
#  0.2: 41.0,
#  0.6: 124.0,
#  0.1: 20.0,
#  0.3: 62.0,
#  0.9: 186.0,
#  0.4: 82.0,
#  0.7: 144.0}

# %%
folds = 5

# %%
config_paths = []
for i, signal_beta in enumerate(seqdatas):
    for fold in range(folds):
        config["name"] = f"K562_ATAC-seq_bias_fold_{fold}" 
        config["seqdata"]["path"] = seqdatas[signal_beta]
        config["seqdata"]["fold"] = f"fold_{fold}"
        config["seqdata"]["max_counts"] = reports[signal_beta]
        curr_out = os.path.join(path_out, f"fold_{fold}", str(round(signal_beta, 1)), f"K562_ATAC-seq_bias_fold_{fold}.yaml")
        os.makedirs(os.path.dirname(curr_out), exist_ok=True)
        with open(curr_out, 'w') as f:
            yaml.dump(config, f)
        print(curr_out)
        config_paths.append(curr_out)
# Out:
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.5/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.5/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.5/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.5/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.5/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.8/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.8/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.8/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.8/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.8/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.2/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.2/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.2/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.2/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.2/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.6/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.6/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.6/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.6/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.6/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.1/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.1/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.1/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.1/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.1/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.3/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.3/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.3/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.3/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.3/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.9/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.9/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.9/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.9/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.9/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.4/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.4/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.4/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.4/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.4/K562_ATAC-seq_bias_fold_4.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.7/K562_ATAC-seq_bias_fold_0.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.7/K562_ATAC-seq_bias_fold_1.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.7/K562_ATAC-seq_bias_fold_2.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.7/K562_ATAC-seq_bias_fold_3.yaml
# /cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.7/K562_ATAC-seq_bias_fold_4.yaml

# %%
# Keep only fold_0 configs
#config_paths = sorted([c for c in config_paths if "fold_0" in c])
#config_paths

# %%
# Keep only 0.5 signal_beta configs
config_paths = sorted([c for c in config_paths if "0.5" in c])
config_paths
# Out:
# ['/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_0/0.5/K562_ATAC-seq_bias_fold_0.yaml',
#  '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_1/0.5/K562_ATAC-seq_bias_fold_1.yaml',
#  '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_2/0.5/K562_ATAC-seq_bias_fold_2.yaml',
#  '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_3/0.5/K562_ATAC-seq_bias_fold_3.yaml',
#  '/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/bias_model/fold_4/0.5/K562_ATAC-seq_bias_fold_4.yaml']

# %%
# Make a dataframe with paths of configs in first column and output directory in second column
df = pd.DataFrame()
df["config"] = config_paths
df["out_dir"] = [os.path.dirname(p) for p in config_paths]
df.to_csv("/cellar/users/aklie/projects/ML4GLand/tutorials/bulk_atac_basepair/eugene/batch/metadata/bias_fit.tsv", sep="\t", index=False, header=False)

# %% [markdown]
# # ChromBPNet configs

# %% [markdown]
# # DONE!

# %% [markdown]
# ---
